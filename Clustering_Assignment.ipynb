# %% [markdown]
# # Question 2 (Airline data)

# %%
# importing libraries
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('E:\\excelr\\Excelr Assignments\\Airlines.csv')
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.info()

# %%
# dropping the ID column
df= df.drop(['ID#'],axis=1)
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# dropping the Award column
df= df.drop(['Award?'],axis=1)
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# ...

# %% [markdown]
# # Heriarcial clustering on airline data

# %%
# Normalization function
def minmax_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
def_norm = minmax_func(df)
def_norm[0:10]
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0  0.016508         0.0       0.00        0.0        0.0     0.000660
# 1  0.011288         0.0       0.00        0.0        0.0     0.000815
# 2  0.024257         0.0       0.00        0.0        0.0     0.015636
# 3  0.008667         0.0       0.00        0.0        0.0     0.001896
# 4  0.057338         0.0       0.75        0.0        0.0     0.164211
# 5  0.009631         0.0       0.00        0.0        0.0     0.000000
# 6  0.049808         0.0       0.50        0.0        0.0     0.104223
# 7  0.012233         0.0       0.00        0.0        0.0     0.019910
# 8  0.259850         0.0       0.50        0.5        0.0     0.006648
# 9  0.061507         0.0       0.50        0.0        0.0     0.107803
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# 0     0.011628           0.000000         0.000000           0.843742
# ...

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
plt.figure(figsize=(20, 7))  
dendogram=sch.dendrogram(sch.linkage(def_norm,'complete'))

# %%
# I have selected 5 clusters
hc = AgglomerativeClustering(n_clusters=5,affinity ='euclidean',linkage ='complete')
hc
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=5)

# %%
y_hc = hc.fit_predict(def_norm)
y_hc
# Out:
# array([2, 2, 2, ..., 0, 2, 2], dtype=int64)

# %%
df['h_clusterid'] = y_hc
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df.groupby('h_clusterid').mean()
# Out:
#                    Balance   Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# h_clusterid
# 0            106776.901163   149.668605   3.667151   1.001453   1.001453
# 1            141021.000000     0.000000   3.642857   1.000000   4.142857
# 2             52499.307781   137.437211   1.201079   1.021572   1.001156
# 3            131999.500000   347.000000   2.500000   1.000000   1.000000
# 4            957355.333333  1355.000000   1.222222   1.000000   1.000000
#
#               Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# h_clusterid
# 0            38389.199128    18.653343         477.122093         1.428052
# 1            97132.785714    28.214286         378.571429         1.071429
# 2             5388.251541     7.672188         414.703005         1.245763
# 3            65634.250000    69.250000       19960.000000        49.250000
# 4            14267.222222    15.555556        2392.666667         9.111111
#
#              Days_since_enroll
# h_clusterid
# ...

# %% [markdown]
# # KMean Clustering On Airline data

# %%
from matplotlib import pyplot as pltfr
from sklearn.cluster import KMeans

# %%
df_1 = pd.read_csv('E:\\excelr\\Excelr Assignments\\Airlines.csv')
df_1
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
# dropping the ID and award column
df_1= df_1.drop(['ID#'],axis=1)
df_1= df_1.drop(['Award?'],axis=1)
df_1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# ...

# %%
# Minmax function
def minmax_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
# StandardScaler function
def norm_func(i):
    x = (i-i.mean())/(i.std())
    return (x)

# %%
x_1 = norm_func(df_1)
x_1
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451084   -0.186275  -0.769482   -0.09823  -0.062759    -0.702698
# 1    -0.539389   -0.186275  -0.769482   -0.09823  -0.062759    -0.701001
# 2    -0.319991   -0.186275  -0.769482   -0.09823  -0.062759    -0.539185
# 3    -0.583726   -0.186275  -0.769482   -0.09823  -0.062759    -0.689200
# 4     0.239648   -0.186275   1.409295   -0.09823  -0.062759     1.082986
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547010   -0.186275  -0.769482   -0.09823  -0.062759    -0.356915
# 3995 -0.091454   -0.186275  -0.769482   -0.09823  -0.062759    -0.669284
# 3996 -0.000043   -0.186275   0.683036   -0.09823  -0.062759     0.343761
# 3997 -0.185584   -0.186275  -0.769482   -0.09823  -0.062759    -0.689200
# 3998 -0.700420   -0.186275  -0.769482   -0.09823  -0.062759    -0.709903
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# ...

# %%
# WCSS ( within cluster sum of square)
wcss=[]
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(x_1)
    wcss.append(kmeans.inertia_)
    
print(wcss)
plt.plot(range(1,11),wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# [39980.00000000028, 32080.255623647, 27551.873761534385, 23801.857217806653, 20343.696754666595, 17720.443501934817, 15867.160994680722, 14355.554147830553, 13224.72885762351, 12142.522046338489]

# %%
# Build Cluster Algorithm
Clusters_new =KMeans(5,random_state =0)
Clusters_new.fit(x_1)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
Clusters_new.labels_
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# Assign clusters to the data set 
df_1['Clustersid_new']=Clusters_new.labels_
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Mean of all the four clusters

df_1.groupby('Clustersid_new').agg(['mean']).reset_index()
# Out:
#   Clustersid_new        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                            mean        mean      mean      mean      mean
# 0              0  115120.838137  139.334072  3.674797  1.000000  1.001478
# 1              1   42727.317304  106.555282  1.160707  1.000000  1.000411
# 2              2  138061.400000   78.800000  3.466667  1.000000  4.066667
# 3              3  190871.212903  815.251613  2.187097  1.000000  1.000000
# 4              4   68876.581395   23.255814  1.139535  2.348837  1.000000
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  38073.246859   18.682188        319.985957        0.962306
# 1   4136.191533    6.466091        212.853679        0.646938
# 2  93927.866667   28.066667        506.666667        1.600000
# 3  31904.529032   27.174194       5524.490323       16.116129
# 4  14689.837209   17.534884        582.627907        2.209302
#
# ...

# %% [markdown]
# # DBSCAN clustering on airline data

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df_2 = pd.read_csv('E:\\excelr\\Excelr Assignments\\Airlines.csv')
df_2
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
# dropping the ID and award column
df_2= df_2.drop(['ID#'],axis=1)
df_2= df_2.drop(['Award?'],axis=1)
df_2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# ...

# %%
data_2 = df_2.values
data_2
# Out:
# array([[28143,     0,     1, ...,     0,     0,  7000],
#        [19244,     0,     1, ...,     0,     0,  6968],
#        [41354,     0,     1, ...,     0,     0,  7034],
#        ...,
#        [73597,     0,     3, ...,     0,     0,  1402],
#        [54899,     0,     1, ...,   500,     1,  1401],
#        [ 3016,     0,     1, ...,     0,     0,  1398]], dtype=int64)

# %%
stscaler = StandardScaler().fit(data_2)
X = stscaler.transform(data_2)
X
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01,  1.39545434e+00],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01,  1.37995704e+00],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01,  1.41192021e+00],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.28603258e-01, -3.62167870e-01, -1.31560393e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          2.85309024e-02, -9.85033311e-02, -1.31608822e+00],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01, -1.31754109e+00]])

# %%
dbscan = DBSCAN(eps=3,min_samples = 5)
dbscan.fit(X)
# Out:
# DBSCAN(eps=3)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
df_2['Cluster']=pd.DataFrame(dbscan.labels_)
df_2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df_2['Cluster'].value_counts()
# Out:
#  0    3902
# -1      58
#  2      25
#  1      14
# Name: Cluster, dtype: int64

# %%
# find the percentage of noise point
(len(df_2[df_2['Cluster']==-1])/len(df_2))*100
# Out:
# 1.4503625906476618

# %%
X=metrics.silhouette_score(X,dbscan.labels_)
X
# Out:
# 0.5767147191313959

# %%
def dbscan(X,eps,min_samples):
    ss=StandardScaler()
    X=ss.fit_transform(X)
    db=DBSCAN(eps=eps,min_samples=min_samples)
    db.fit(X)
    y_pred=db.fit_predict(X)
    plt.scatter(X[:,0],X[:,1],c=y_pred,cmap='Paired')
    plt.title('DBSCAN')

# %%
dbscan(data_2,5,12)

# %% [markdown]
# from this we can conclude that there will be three clusters with clusterid 0,1 and 2 and 58 outliers.
